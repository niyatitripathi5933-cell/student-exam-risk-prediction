# %%
import pandas as pd

df = pd.read_csv("../data/student_data.csv")
df.head()
# Out:
#    Student_ID  Attendance  Internal_Marks  Assignment_Score  Study_Hours  \
# 0         101          85              78                80            3
# 1         102          60              45                50            1
# 2         103          92              88                90            4
# 3         104          55              40                45            1
# 4         105          75              70                72            2
#
#   Final_Result
# 0         Pass
# 1         Fail
# 2         Pass
# 3         Fail
# 4         Pass
